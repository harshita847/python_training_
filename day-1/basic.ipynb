# %%
name= input ("enter your name-")
age=int (input("enter your age-"))
print("my name is",name,"my age is",age)
# Out:
# my name is harshita jain my age is 18

# %%
# write a program to take principle rate time and calculate simple interest

p =int(input("enter principle amount"))
r=float(input("enter rate"))
t= float(input("enter time"))
print("principle",p)
print("rate",r)
print("time",t)
interest= (p*r*t)/100
print(int(interest))
# Out:
# principle 100
# rate 3.0
# time 6.0
# 18

# %%
#write a program which will take age as a input and check whether it is eligible for vote
age= int(input("enter your age-"))
if age>18 :
    print("eligible to vote")
else :
    print("not eligible to vote")
# Out:
# eligible to vote

# %%
year=int(input("enter year"))
if (year%400==0) or (year %4==0 and year % 100!=0):
    print("it is a leap year")
else:
    print("not a leap year")
# Out:
# it is a leap year

# %%
year=int(input("enter year"))
if (year%400==0):
    print("it is a leap year")
elif year %4==0 and year % 100!=0:
    print("leap")
else:
    print("not a leap year")
# Out:
# not a leap year

# %%
unit=int(input("enter units "))
if unit>0 and unit<=50:
    total=unit*0.5
elif unit>50 and unit<=200:
    total=50*0.5+(unit-50)*0.75
elif unit>200 and unit<=450:
    total=50*0.5+150*0.75+(unit-200)*1.2
else :
    total=50*0.5+150*0.75+250*1.2+(unit-450)*1.5

print(total+total*0.2)
# Out:
# 309.0

# %%
# list1=[2,3,4,2,5,6,7,8,6]
for i in range(2,20,2):
    print(i,end=" " )
# Out:
# 2 4 6 8 10 12 14 16 18

# %%
sum=0
for i in range(6,50,2):
    sum+=i
print(sum)
# Out:
# 594

# %%
#wap which will print fizz if the number is divible y 3 and 

for n in range(1,21,1):
    if n%3==0 and n%5==0:
        print("fizz buzz")
    elif n%3==0:
        print("fizz")
    elif n%5==0:
        print("buzz")
    else:
        print(n)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizz buzz
# 16
# 17
# fizz
# 19
# buzz
