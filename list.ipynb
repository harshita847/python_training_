# %%
l1=[7,-4,-2,9,0,11,17,8,19,10]
print(l1[1::4])
# Out:
# [-4, 11, 10]

# %%
l1=[7,-4,-2,9,0,11,17,8,19,10]
l1.append(20)  # add at last
l1.insert(3,45) 
l2=[10,20,30]
l3=[1,2]
l1=l1+l3
l1.extend(l2)  # to add more than one element in form list
print(l1)
# Out:
# [7, -4, -2, 45, 9, 0, 11, 17, 8, 19, 10, 20, 1, 2, 10, 20, 30]
