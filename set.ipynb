# %%
l1={1,2,3,4,5,6}
print(l1)
l1.add(10)
print(l1)
l1.update([11,12,45])
print(l1)
l1.remove(5)
print(l1)
l1.pop()
print(l1)
b={10,20,40}
print(l1.union(a))

# %%
# assignment questions

A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}
c=A.intersection(B)
print("intersection of set a and b is:", c)
# Out:
# intersection of set a and b is: {4, 5}

# %%
# assignment questions
#Write a Python program to create two sets, X and Y, and find the elements
#that are unique to each set (not present in both).

X = {10, 20, 30, 40}
Y = {30, 40, 50, 60}
z=X.union(Y)- X.intersection(Y)
print(z)
# Out:
# {10, 50, 20, 60}

# %%
 #Write a Python program to check if all elements of one set are contained
 #within another set.

S1 = {1, 2, 3}
S2 = {1, 2, 3, 4, 5}
c=S1.intersection(S2)
if(c==S1):
    print("yes")
# Out:
# yes

# %%
# Write a Python program which create a new set from given two sets have
# only that elements which are not common.

X = {2, 4, 3}
Y = {1, 3, 5}
z=X.union(Y)- X.intersection(Y)
print(z)
# Out:
# {1, 2, 4, 5}

# %%
# Write a Python program to combine all elements from three different sets
# into one.
Set1 = {1, 2}
Set2 = {2, 3}
Set3 = {3, 4}

new=(Set1 | Set2) |Set3
print(new)
# Out:
# {1, 2, 3, 4}

# %%
# Write a Python program to remove a specific element(n) from a set, but
# only if it exists in the set. 

S = {1, 2, 3, 4, 5}
S.discard(2)
S.discard(7)
print(S)
# Out:
# {1, 3, 4, 5}

# %%
a=eval(input("enter elements in set:"))
print(a)
# Out:
# {1, 2, 3, 'harshita'}
